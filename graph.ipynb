# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1,2,3,4,5,6])
y = np.array(['A','B','C','D','E','F'])

# %%
plt.plot(x,y)

# %%
plt.plot(x, y, marker = '*', ms=20, mec='red', mfc='green')

# %%
plt.plot(x)
plt.plot(y)

# %%
plt.plot(x, y, linestyle = 'dotted', linewidth = 5, color = 'Red')

# %%
plt.scatter(x,y, marker = '*', color = 'orange')

# %%
x1 = np.random.randint(100, size = (5))
y1 = np.random.randint(100, size = (5))

# %%
plt.scatter(x1, y1, color = 'orange')

# %%
plt.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e6a7fc3ef0>,
#   <matplotlib.patches.Wedge at 0x1e6a7e7e150>,
#   <matplotlib.patches.Wedge at 0x1e6a7f51a30>,
#   <matplotlib.patches.Wedge at 0x1e6a7ea7c20>,
#   <matplotlib.patches.Wedge at 0x1e6a7ea4560>,
#   <matplotlib.patches.Wedge at 0x1e6a7ea4860>],
#  [Text(1.087713908390803, 0.16394649582471824, ''),
#   Text(0.9088626448409262, 0.6196520740002058, ''),
#   Text(0.2447729879062314, 1.0724207124032321, ''),
#   Text(-0.8063571098828889, 0.7481899567231004, ''),
#   Text(-0.9088626013289132, -0.6196521378206009, ''),
#   Text(0.6858388884465332, -0.8600145458621175, '')])

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.barh(x,y)
# Out:
# <BarContainer object of 6 artists>

# %%
from sklearn.preprocessing import LabelEncoder

# %%
data1 = {
    'City' : ['delhi', 'Haldwani', 'Dehradun', 'Dehradun', 'Delhi']
}

# %%
df = pd.DataFrame(data1)
print(df)
# Out:
#        City
# 0     delhi
# 1  Haldwani
# 2  Dehradun
# 3  Dehradun
# 4     Delhi

# %%
le = LabelEncoder()
df['labelcity'] = le.fit_transform(df['City'])
print(df)
# Out:
#        City  labelcity
# 0     delhi          3
# 1  Haldwani          2
# 2  Dehradun          0
# 3  Dehradun          0
# 4     Delhi          1

# %%
pd.get_dummies(df['City'] , prefix='City')
# Out:
#    City_Dehradun  City_Delhi  City_Haldwani  City_delhi
# 0          False       False          False        True
# 1          False       False           True       False
# 2           True       False          False       False
# 3           True       False          False       False
# 4          False        True          False       False
