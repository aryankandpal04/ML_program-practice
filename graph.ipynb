# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1,2,3,4,5,6])
y = np.array(['A','B','C','D','E','F'])

# %%
plt.plot(x,y)

# %%
plt.plot(x, y, marker = '*', ms=20, mec='red', mfc='green')

# %%
plt.plot(x)
plt.plot(y)

# %%
plt.plot(x, y, linestyle = 'dotted', linewidth = 5, color = 'Red')

# %%
plt.scatter(x,y, marker = '*', color = 'orange')

# %%
x1 = np.random.randint(100, size = (5))
y1 = np.random.randint(100, size = (5))

# %%
plt.scatter(x1, y1, color = 'orange')

# %%
plt.pie(x1)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e6a95bdd30>,
# ...
#  [Text(1.0260164624501165, 0.3965983091004664, ''),
#   Text(0.6589508458723402, 0.8807858892626105, ''),
#   Text(-0.7028897470422342, 0.8461359249570393, ''),
#   Text(-0.7852017931110115, -0.7703623459744463, ''),
#   Text(0.6589508046397764, -0.8807859201103247, '')])

# %%
plt.bar(x1,y1)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.barh(x1,y1)
# Out:
# <BarContainer object of 5 artists>

# %%
from sklearn.preprocessing import LabelEncoder

# %%
data1 = {
    'City' : ['delhi', 'Haldwani', 'Dehradun', 'Dehradun', 'Delhi']
}

# %%
df = pd.DataFrame(data1)
print(df)
# Out:
#        City
# 0     delhi
# 1  Haldwani
# 2  Dehradun
# 3  Dehradun
# 4     Delhi

# %%
le = LabelEncoder()
df['labelcity'] = le.fit_transform(df['City'])
print(df)
# Out:
#        City  labelcity
# 0     delhi          3
# 1  Haldwani          2
# 2  Dehradun          0
# 3  Dehradun          0
# 4     Delhi          1

# %%
pd.get_dummies(df['City'] , prefix='City')
# Out:
#    City_Dehradun  City_Delhi  City_Haldwani  City_delhi
# 0          False       False          False        True
# 1          False       False           True       False
# 2           True       False          False       False
# 3           True       False          False       False
# 4          False        True          False       False
