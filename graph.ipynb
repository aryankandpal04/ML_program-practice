# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1,2,3,4,5,6])
y = np.array(['A','B','C','D','E','F'])

# %%
plt.plot(x,y)

# %%
plt.plot(x,y, ms = '20', mec='ref', mfc = 'green')
